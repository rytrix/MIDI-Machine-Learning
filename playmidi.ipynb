# %%
from IPython.display import Audio
from pretty_midi import PrettyMIDI

# %%
sf2_path = 'AMS_Steinway_Grand.sf2'
# midi_file = "midis_train/Chesneau, Carl, Lucie, Op.20, sWHbSHF4jTg.mid"
midi_file = "generated.mid"

music = PrettyMIDI(midi_file=midi_file)
waveform = music.fluidsynth(sf2_path=sf2_path)
Audio(waveform, rate=44100)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
